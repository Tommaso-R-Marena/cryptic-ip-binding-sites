# %% [markdown]
# # Quick Start: Cryptic IP Binding Site Detection
#
# This notebook demonstrates basic usage of the pipeline.

# %%
import sys
sys.path.insert(0, '..')

from cryptic_ip.validation import validate_adar2
from cryptic_ip.analysis import ProteinAnalyzer

# %% [markdown]
# ## 1. Validate on ADAR2
#
# First, let's test the pipeline on ADAR2 - the gold standard.

# %%
# This will download ADAR2 structure if needed
results = validate_adar2(use_alphafold=True)

print(f"Validation: {'PASSED' if results['validation_passed'] else 'FAILED'}")

# %% [markdown]
# ## 2. Analyze Your Own Structure
#
# Analyze any PDB file for cryptic IP binding sites.

# %%
# Replace with your PDB file
# analyzer = ProteinAnalyzer('path/to/structure.pdb')

# Detect pockets
# pockets = analyzer.detect_pockets()
# print(f'Found {len(pockets)} pockets')

# Score all pockets
# scored = analyzer.score_all_pockets()
# print(scored.head())

# %% [markdown]
# ## 3. Next Steps
#
# - See notebook 02 for detailed ADAR2 analysis
# - See notebook 03 for proteome screening
