# %% [markdown]
# # Tutorial 06: Web Interface
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tommaso-R-Marena/cryptic-ip-binding-sites/blob/main/notebooks/tutorials/Tutorial_06_Web_Interface.ipynb)
#
# Launch and deploy the Streamlit interface locally, then package for cloud deployment.

# %% [markdown]
# ## Workflow
# - Run Streamlit locally
# - Validate key UI interactions
# - Create deployment config
# - Deploy to Streamlit Community Cloud

# %%
# !pip -q install streamlit

# %%
# !streamlit run streamlit_app.py --server.headless true --server.port 8501

# %%
# For Streamlit Cloud: ensure requirements.txt and .streamlit/config.toml are committed.
